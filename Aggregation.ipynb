# %%
import pandas as pd
df = pd.read_csv("ca_housing_analytical_matrix.csv")

# %%
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street    city  \
# 0      76008.0  for_sale  250000.0  7.0   3.0      0.19  1002149.0  Blythe
# 1      22611.0  for_sale  287500.0  5.0   3.0      0.20  1230938.0  Blythe
# 2      86230.0  for_sale  144549.0  3.0   1.0      0.29   994271.0  Blythe
# 3      81166.0  for_sale  250000.0  3.0   2.0      0.15  1507474.0  Blythe
# 4      81166.0  for_sale  299000.0  3.0   3.0      0.13  1612233.0  Blythe
#
#         state  zip_code  ...  sold_month median_hh_income  \
# 0  California   92225.0  ...           9          69744.0
# 1  California   92225.0  ...           3          79601.0
# 2  California   92225.0  ...           2          96000.0
# 3  California   92225.0  ...           9          80090.0
# 4  California   92225.0  ...           7          90002.0
#
#    urban_density_ratio  state_in_migration_rate  west_cpi_inflation  \
# 0             0.971108                 0.025059             244.257
# ...

# %%
df.shape
df.columns
# Out:
# Index(['brokered_by', 'status', 'price', 'bed', 'bath', 'acre_lot', 'street',
#        'city', 'state', 'zip_code', 'house_size', 'prev_sold_date',
#        'sold_year', 'sold_month', 'median_hh_income', 'urban_density_ratio',
#        'state_in_migration_rate', 'west_cpi_inflation',
#        'us_30yr_mortgage_rate', 'ca_unemployment_rate', 'log_price',
#        'log_house_size', 'is_cost_burdened'],
#       dtype='str')
